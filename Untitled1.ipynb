# %% [markdown]
# <a href="https://colab.research.google.com/github/LfyZoio/Projects/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list = [ 10,20,50,90 ]
for l in enumerate(list):
    print(l)
# Out:
# (0, 10)
# (1, 20)
# (2, 50)
# (3, 90)
