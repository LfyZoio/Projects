# %% [markdown]
# <a href="https://colab.research.google.com/github/LfyZoio/Projects/blob/main/Project%20%231.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
soma1 = 10
soma2 = 10
sun = (soma1 + soma2)
media = (sun/2)
print(media)
# Out:
# 10.0
