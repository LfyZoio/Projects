# %% [markdown]
# <a href="https://colab.research.google.com/github/LfyZoio/Projects/blob/main/Algoritmos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N1 = 5
N2 = 10
N3 = 5
soma = N1+N2+N3
if soma <= 15 :
  print("número satisfatório")
else :
  print("número insatisfatório")
# Out:
# número insatisfatório
